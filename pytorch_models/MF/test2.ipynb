# %%
import pandas as pd
import torch
import torch.nn as nn


from bpr_opt import config
from bpr_opt import MF
from bpr_opt import retrain_model
from bpr_opt import predict_recommendations

import warnings
warnings.filterwarnings(action = 'ignore')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# 모델 불러오기
model = MF(6040, 3706, config.k).to(device)
model.load_state_dict(torch.load('MF_parameters.pt'))

all_items = [i for i in range(3706)]

# 데이터 불러오기
data = pd.read_table('./../../data/ml-1m/ratings.dat',sep='::',header=None, names=['uid','iid','r','ts'],encoding='latin-1')

user_encoder = {id:idx for idx, id in enumerate(data['uid'].unique())}
user_decoder = {idx:id for id, idx in user_encoder.items()}

item_encoder = {id:idx for idx, id in enumerate(data['iid'].unique())}
item_decoder = {idx:id for id, idx in item_encoder.items()}
split = [1, 2, 3, 5]
recommended_items = retrain_model(model, split, num_recommendations=10)
print(recommended_items)
# Out:
# MF(
#   (user_emb): Embedding(6040, 64)
#   (item_emb): Embedding(3706, 64)
#   (predict_layer): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=False)
#   )
# )
# MF(
#   (user_emb): Embedding(6040, 64)
#   (item_emb): Embedding(3706, 64)
#   (predict_layer): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=False)
#   )
# )
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_407829/3218732499.py in <module>
#      29 item_decoder = {idx:id for id, idx in item_encoder.items()}
#      30 split = [1, 2, 3, 5]
# ---> 31 recommended_items = retrain_model(model, split, num_recommendations=10)
#      32 print(recommended_items)
#
# /home/recsys_service_deployment-main_NGCF/recsys_service_deployment-main/pytorch_models/MF/bpr_opt.py in retrain_model(model, interacted_items, num_recommendations, num_epochs, learning_rate)
#     148
#     149     config.num_users += 1
# --> 150     print("config.num_users : ",config.num_users)
#     151     pred_bpr_loss_func = BPR_loss()
#     152
#
# UnboundLocalError: local variable 'user_id' referenced before assignment

# %%
split = [1, 3, 9, 5]
recommended_items = retrain_model(model, split, num_recommendations=10)
print(recommended_items)
# Out:
# MF(
#   (user_emb): Embedding(6040, 64)
#   (item_emb): Embedding(3706, 64)
#   (predict_layer): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=False)
#   )
# )
# MF(
#   (user_emb): Embedding(6040, 64)
#   (item_emb): Embedding(3706, 64)
#   (predict_layer): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=False)
#   )
# )
# config.num_users :  6040
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_401079/2378812661.py in <module>
#       1 split = [1, 3, 9, 5]
# ----> 2 recommended_items = retrain_model(model, split, num_recommendations=10)
#       3 print(recommended_items)
#
# /home/recsys_service_deployment-main_NGCF/recsys_service_deployment-main/pytorch_models/MF/bpr_opt.py in retrain_model(model, interacted_items, num_recommendations, num_epochs, learning_rate)
#     184           # BPR Loss 계산
#     185           pred_loss = pred_bpr_loss_func(pos_output, neg_output)
# --> 186           pred_loss.backward()
#     187           optimizer.step()
#     188
#
# /opt/conda/envs/pyt/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     487             )
#     488         torch.autograd.backward(
# --> 489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#     491
#
# /opt/conda/envs/pyt/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     200
#     201 def grad(
#
# RuntimeError: The size of tensor a (6041) must match the size of tensor b (6042) at non-singleton dimension 0
